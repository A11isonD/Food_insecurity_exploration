# %%
import pandas as pd

df = pd.read_csv('MMG2025_2019-2023_Data_To_Share_County_CSV.csv', encoding='latin-1')

print(df)
# Out:
#         FIPS State            County, State  Year  \
# 0       1001    AL  Autauga County, Alabama  2019
# 1       1001    AL  Autauga County, Alabama  2020
# 2       1001    AL  Autauga County, Alabama  2021
# 3       1001    AL  Autauga County, Alabama  2022
# 4       1001    AL  Autauga County, Alabama  2023
# ...      ...   ...                      ...   ...
# 15711  56045    WY   Weston County, Wyoming  2019
# 15712  56045    WY   Weston County, Wyoming  2020
# 15713  56045    WY   Weston County, Wyoming  2021
# 15714  56045    WY   Weston County, Wyoming  2022
# 15715  56045    WY   Weston County, Wyoming  2023
#
#       Overall Food Insecurity Rate # of Food Insecure Persons Overall  \
# 0                            15.7%                              8,670
# 1                            14.5%                              8,070
# 2                            13.3%                              7,770
# 3                            15.1%                              8,860
# ...

# %%
df.head()
# Out:
#    FIPS State            County, State  Year Overall Food Insecurity Rate  \
# 0  1001    AL  Autauga County, Alabama  2019                        15.7%
# 1  1001    AL  Autauga County, Alabama  2020                        14.5%
# 2  1001    AL  Autauga County, Alabama  2021                        13.3%
# 3  1001    AL  Autauga County, Alabama  2022                        15.1%
# 4  1001    AL  Autauga County, Alabama  2023                        15.1%
#
#   # of Food Insecure Persons Overall  \
# 0                              8,670
# 1                              8,070
# 2                              7,770
# 3                              8,860
# 4                              8,970
#
#   Food Insecurity Rate among Black Persons (all ethnicities)  \
# 0                                                26%
# 1                                                25%
# 2                                                23%
# 3                                                23%
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15716 entries, 0 to 15715
# Data columns (total 24 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   FIPS                                                        15716 non-null  int64
#  1   State                                                       15716 non-null  str
#  2   County, State                                               15716 non-null  str
#  3   Year                                                        15716 non-null  int64
#  4   Overall Food Insecurity Rate                                15715 non-null  str
#  5   # of Food Insecure Persons Overall                          15715 non-null  str
#  6   Food Insecurity Rate among Black Persons (all ethnicities)  7432 non-null   str
#  7   Food Insecurity Rate among Hispanic Persons (any race)      8915 non-null   str
# ...

# %%
df.shape
# Out:
# (15716, 24)

# %%
df['County, State'].value_counts()
# Out:
# County, State
# Autauga County, Alabama                                   5
# Baldwin County, Alabama                                   5
# Barbour County, Alabama                                   5
# Bibb County, Alabama                                      5
# Blount County, Alabama                                    5
#                                                          ..
# South Central Connecticut Planning Region, Connecticut    2
# Southeastern Connecticut Planning Region, Connecticut     2
# Western Connecticut Planning Region, Connecticut          2
# Doña Ana County, New Mexico                               2
# Valdez-Cordova Census Area, Alaska                        1
# Name: count, Length: 3154, dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# TX    1270
# GA     795
# VA     665
# KY     600
# MO     575
# KS     525
# IL     510
# NC     500
# IA     495
# TN     475
# NE     465
# IN     460
# OH     440
# MN     435
# MI     415
# MS     410
# OK     385
# AR     375
# WI     360
# AL     335
# FL     335
# PA     335
# SD     330
# CO     320
# LA     320
# NY     310
# CA     290
# MT     280
# WV     275
# ND     265
# SC     230
# ID     220
# WA     195
# OR     180
# NM     165
# AK     149
# UT     145
# MD     120
# WY     115
# NJ     105
# NV      85
# ME      80
# AZ      75
# MA      70
# VT      70
# NH      50
# CT      42
# HI      25
# RI      25
# DE      15
# DC       5
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                FIPS          Year  Rural-Urban Continuum Code (2013)  \
# count  15716.000000  15716.000000                       15694.000000
# mean   30373.833927   2021.000318                           5.011979
# std    15166.194087      1.414236                           2.707610
# min     1001.000000   2019.000000                           1.000000
# 25%    18175.000000   2020.000000                           2.000000
# 50%    29175.000000   2021.000000                           6.000000
# 75%    45081.000000   2022.000000                           7.000000
# max    56045.000000   2023.000000                           9.000000
#
#        Rural-Urban Continuum Code (2023)
# count                        6288.000000
# mean                            5.249046
# std                             2.929423
# min                             1.000000
# 25%                             2.000000
# 50%                             6.000000
# 75%                             8.000000
# ...

# %%
df.loc[4971:5570]
#Kentucky counties
# Out:
#        FIPS State              County, State  Year  \
# 4971  21001    KY     Adair County, Kentucky  2019
# 4972  21001    KY     Adair County, Kentucky  2020
# 4973  21001    KY     Adair County, Kentucky  2021
# 4974  21001    KY     Adair County, Kentucky  2022
# 4975  21001    KY     Adair County, Kentucky  2023
# ...     ...   ...                        ...   ...
# 5566  21239    KY  Woodford County, Kentucky  2019
# 5567  21239    KY  Woodford County, Kentucky  2020
# 5568  21239    KY  Woodford County, Kentucky  2021
# 5569  21239    KY  Woodford County, Kentucky  2022
# 5570  21239    KY  Woodford County, Kentucky  2023
#
#      Overall Food Insecurity Rate # of Food Insecure Persons Overall  \
# 4971                        16.7%                              3,210
# 4972                        15.2%                              2,950
# 4973                        13.7%                              2,590
# 4974                        18.0%                              3,400
# ...

# %%
df.columns.tolist()
# Out:
# ['FIPS',
#  'State',
#  'County, State',
#  'Year',
#  'Overall Food Insecurity Rate',
#  '# of Food Insecure Persons Overall',
#  'Food Insecurity Rate among Black Persons (all ethnicities)',
#  'Food Insecurity Rate among Hispanic Persons (any race)',
#  'Food Insecurity Rate among White, non-Hispanic Persons',
#  'SNAP Threshold',
#  '% FI ? SNAP Threshold',
#  '% FI > SNAP Threshold',
#  'Child Food Insecurity Rate',
#  '# of Food Insecure Children',
#  '% food insecure children in HH w/ HH incomes below 185 FPL',
#  '% food insecure children in HH w/ HH incomes above 185 FPL',
#  'Cost Per Meal',
#  'Weighted weekly $ needed by FI',
#  'Weighted Annual Food Budget Shortfall',
#  'Rural-Urban Continuum Code (2013)',
#  'Rural-Urban Continuum Code (2023)',
#  'Census Region',
#  'Census Division',
#  'FNS Region']

# %%
df.iloc[0:3, 0:2]
# Out:
#    FIPS State
# 0  1001    AL
# 1  1001    AL
# 2  1001    AL

# %%
df.sort_values(by=['Overall Food Insecurity Rate'], ascending=[True])
# Out:
#         FIPS State                       County, State  Year  \
# 2363   13171    GA               Lamar County, Georgia  2021
# 4409   19183    IA             Washington County, Iowa  2022
# 10039  38033    ND  Golden Valley County, North Dakota  2022
# 8688   31165    NE              Sioux County, Nebraska  2021
# 1354    8051    CO           Gunnison County, Colorado  2019
# ...      ...   ...                                 ...   ...
# 3350   17147    IL              Piatt County, Illinois  2023
# 14139  51013    VA          Arlington County, Virginia  2022
# 1269    8017    CO           Cheyenne County, Colorado  2019
# 8188   30077    MT              Powell County, Montana  2021
# 2750   15005    HI              Kalawao County, Hawaii  2023
#
#       Overall Food Insecurity Rate # of Food Insecure Persons Overall  \
# 2363                         10.0%                              1,850
# 4409                         10.0%                              2,260
# ...

# %% [markdown]
# ['State',
#  'County, State',
#  'Year',
#  'Overall Food Insecurity Rate',
#  '# of Food Insecure Persons Overall',
#  'Food Insecurity Rate among Black Persons (all ethnicities)',
#  'Food Insecurity Rate among Hispanic Persons (any race)',
#  'Food Insecurity Rate among White, non-Hispanic Persons',
#  'SNAP Threshold',
#  '% FI ? SNAP Threshold',
#  '% FI > SNAP Threshold',
#  'Child Food Insecurity Rate',
#  '# of Food Insecure Children',
#  '% food insecure children in HH w/ HH incomes below 185 FPL',
#  '% food insecure children in HH w/ HH incomes above 185 FPL',
#  'Cost Per Meal',
#  'Weighted weekly $ needed by FI',
#  'Weighted Annual Food Budget Shortfall',
#  'Rural-Urban Continuum Code (2013)',
#  'Rural-Urban Continuum Code (2023)',
#  'Census Region',
#  'Census Division',
#  'FNS Region']

# %%
df.drop('FIPS', axis='columns')
# Out:
#       State            County, State  Year Overall Food Insecurity Rate  \
# 0        AL  Autauga County, Alabama  2019                        15.7%
# 1        AL  Autauga County, Alabama  2020                        14.5%
# 2        AL  Autauga County, Alabama  2021                        13.3%
# 3        AL  Autauga County, Alabama  2022                        15.1%
# 4        AL  Autauga County, Alabama  2023                        15.1%
# ...     ...                      ...   ...                          ...
# 15711    WY   Weston County, Wyoming  2019                        12.2%
# 15712    WY   Weston County, Wyoming  2020                        11.0%
# 15713    WY   Weston County, Wyoming  2021                        10.2%
# 15714    WY   Weston County, Wyoming  2022                        13.6%
# 15715    WY   Weston County, Wyoming  2023                        13.9%
#
#        # of Food Insecure Persons Overall  \
# 0                                    8670
# ...

# %%
df.dtypes
# Out:
# FIPS                                                            int64
# State                                                             str
# County, State                                                     str
# Year                                                            int64
# Overall Food Insecurity Rate                                      str
# # of Food Insecure Persons Overall                              Int64
# Food Insecurity Rate among Black Persons (all ethnicities)        str
# Food Insecurity Rate among Hispanic Persons (any race)            str
# Food Insecurity Rate among White, non-Hispanic Persons            str
# SNAP Threshold                                                    str
# % FI ? SNAP Threshold                                             str
# % FI > SNAP Threshold                                             str
# Child Food Insecurity Rate                                        str
# ...

# %%
df.isna()
# Out:
#         FIPS  State  County, State   Year  Overall Food Insecurity Rate  \
# 0      False  False          False  False                         False
# 1      False  False          False  False                         False
# 2      False  False          False  False                         False
# 3      False  False          False  False                         False
# 4      False  False          False  False                         False
# ...      ...    ...            ...    ...                           ...
# 15711  False  False          False  False                         False
# 15712  False  False          False  False                         False
# 15713  False  False          False  False                         False
# 15714  False  False          False  False                         False
# 15715  False  False          False  False                         False
#
#        # of Food Insecure Persons Overall  \
# 0                                   False
# ...

# %%
df.isnull()
# Out:
#         FIPS  State  County, State   Year  Overall Food Insecurity Rate  \
# 0      False  False          False  False                         False
# 1      False  False          False  False                         False
# 2      False  False          False  False                         False
# 3      False  False          False  False                         False
# 4      False  False          False  False                         False
# ...      ...    ...            ...    ...                           ...
# 15711  False  False          False  False                         False
# 15712  False  False          False  False                         False
# 15713  False  False          False  False                         False
# 15714  False  False          False  False                         False
# 15715  False  False          False  False                         False
#
#        # of Food Insecure Persons Overall  \
# 0                                   False
# ...

# %%
null_rows = df[df['# of Food Insecure Persons Overall'].isnull()]
print(null_rows)
# Out:
#        FIPS State           County, State  Year Overall Food Insecurity Rate  \
# 2750  15005    HI  Kalawao County, Hawaii  2023                          NaN
#
#      # of Food Insecure Persons Overall  \
# 2750                                NaN
#
#      Food Insecurity Rate among Black Persons (all ethnicities)  \
# 2750                                                NaN
#
#      Food Insecurity Rate among Hispanic Persons (any race)  \
# 2750                                                NaN
#
#      Food Insecurity Rate among White, non-Hispanic Persons SNAP Threshold  \
# 2750                                                NaN               200%
#
#       ... % food insecure children in HH w/ HH incomes below 185 FPL  \
# 2750  ...                                                NaN
#
#      % food insecure children in HH w/ HH incomes above 185 FPL Cost Per Meal  \
# 2750                                                NaN                 $5.29
#
# ...

# %%
null_rows = df[df['# of Food Insecure Children'].isnull()]
print(null_rows)
# Out:
#         FIPS State                  County, State  Year  \
# 1363    8053    CO      Hinsdale County, Colorado  2023
# 2750   15005    HI         Kalawao County, Hawaii  2023
# 8170   30069    MT      Petroleum County, Montana  2023
# 8505   31091    NE        Hooker County, Nebraska  2023
# 8565   31115    NE          Loup County, Nebraska  2023
# 8705   31171    NE        Thomas County, Nebraska  2023
# 9975   38007    ND  Billings County, North Dakota  2023
# 12885  48105    TX         Crockett County, Texas  2023
# 13275  48261    TX           Kenedy County, Texas  2023
# 13280  48263    TX             Kent County, Texas  2023
# 13295  48269    TX             King County, Texas  2023
# 13300  48271    TX           Kinney County, Texas  2023
# 13375  48301    TX           Loving County, Texas  2023
# 13420  48319    TX            Mason County, Texas  2023
# 13700  48431    TX         Sterling County, Texas  2023
# 13730  48443    TX          Terrell County, Texas  2023
#
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15711    False
# 15712    False
# 15713    False
# 15714    False
# 15715    False
# Length: 15716, dtype: bool

# %%
duplicates = df[df.duplicated()]
print(duplicates)
#This means there are no duplicates
# Out:
# Empty DataFrame
# Columns: [FIPS, State, County, State, Year, Overall Food Insecurity Rate, # of Food Insecure Persons Overall, Food Insecurity Rate among Black Persons (all ethnicities), Food Insecurity Rate among Hispanic Persons (any race), Food Insecurity Rate among White, non-Hispanic Persons, SNAP Threshold, % FI ? SNAP Threshold, % FI > SNAP Threshold, Child Food Insecurity Rate, # of Food Insecure Children, % food insecure children in HH w/ HH incomes below 185 FPL, % food insecure children in HH w/ HH incomes above 185 FPL, Cost Per Meal, Weighted weekly $ needed by FI, Weighted Annual Food Budget Shortfall, Rural-Urban Continuum Code (2013), Rural-Urban Continuum Code (2023), Census Region, Census Division, FNS Region]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['# of Food Insecure Persons Overall'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# Removed commas from numerical values, changed those values from strings to integers

# %%
#ser = pd.Series(df['# of Food Insecure Persons Overall']).head().strip()
#pd.to_numeric(ser)
#ser
#avg = df['# of Food Insecure Persons Overall'].mean()
#print(avg)

df['# of Food Insecure Persons Overall'] = df['# of Food Insecure Persons Overall'].str.replace(',', '')

df['# of Food Insecure Persons Overall'] = df['# of Food Insecure Persons Overall'].astype('Int64')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15716 entries, 0 to 15715
# Data columns (total 24 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   FIPS                                                        15716 non-null  int64
#  1   State                                                       15716 non-null  str
#  2   County, State                                               15716 non-null  str
#  3   Year                                                        15716 non-null  int64
#  4   Overall Food Insecurity Rate                                15715 non-null  str
#  5   # of Food Insecure Persons Overall                          15715 non-null  Int64
#  6   Food Insecurity Rate among Black Persons (all ethnicities)  7432 non-null   str
#  7   Food Insecurity Rate among Hispanic Persons (any race)      8915 non-null   str
# ...

# %% [markdown]
# Removed commas from numerical values, changed those values from strings to integers

# %%
#ser = pd.Series(df['# of Food Insecure Persons Overall']).head().strip()
#pd.to_numeric(ser)
#ser

#avg = df['# of Food Insecure Persons Overall'].mean()
#print(avg)

df['# of Food Insecure Children'] = df['# of Food Insecure Children'].str.replace(',', '')

df['# of Food Insecure Children'] = df['# of Food Insecure Children'].astype('Int64')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15716 entries, 0 to 15715
# Data columns (total 24 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   FIPS                                                        15716 non-null  int64
#  1   State                                                       15716 non-null  str
#  2   County, State                                               15716 non-null  str
#  3   Year                                                        15716 non-null  int64
#  4   Overall Food Insecurity Rate                                15715 non-null  str
#  5   # of Food Insecure Persons Overall                          15715 non-null  Int64
#  6   Food Insecurity Rate among Black Persons (all ethnicities)  7432 non-null   str
#  7   Food Insecurity Rate among Hispanic Persons (any race)      8915 non-null   str
# ...

# %%
df.dtypes
# Out:
# FIPS                                                            int64
# State                                                             str
# County, State                                                     str
# Year                                                            int64
# Overall Food Insecurity Rate                                      str
# # of Food Insecure Persons Overall                                str
# Food Insecurity Rate among Black Persons (all ethnicities)        str
# Food Insecurity Rate among Hispanic Persons (any race)            str
# Food Insecurity Rate among White, non-Hispanic Persons            str
# SNAP Threshold                                                    str
# % FI ? SNAP Threshold                                             str
# % FI > SNAP Threshold                                             str
# Child Food Insecurity Rate                                        str
# ...

# %% [markdown]
# Renamed columns for better readability.

# %%
df.rename(columns={'Overal FI Rate': 'Overall FI Rate',
                   '# of Food Insecure Persons Overall': '# FI Persons Overall',
                   'Food Insecurity Rate among Black Persons (all ethnicities)': 'FI Rate Blk (all ethn)',
                   'Food Insecurity Rate among Hispanic Persons (any race)': 'FI Hsp (any race)',
                   'Food Insecurity Rate among White, non-Hispanic Persons': 'FI Rate Wht, non-Hsp',
                   'SNAP Threshold': 'SNAP Thresh.', 
                   '% food insecure children in HH w/ HH incomes below 185 FPL': '% FI Children HH w/$ < 185 FPL',
                   '% food insecure children in HH w/ HH incomes above 185 FPL': '% FI Children HH w/$ > 185 FPL',
                   'Child Food Insecurity Rate': 'Child FI Rate',
                   '# of Food Insecure Children': '# FI Children',
                   'Cost Per Meal': '$ Per Meal',
                   'Weighted weekly $ needed by FI': 'Wghtd Wkly $ Needed by FI',
                   'Weighted Annual Food Budget Shortfall': 'Wghtd Annual Food Budg Shortfall',
                   'Rural-Urban Continuum Code (2013)': 'Rur-Urb Cont. Code (2013)',
                   'Rural-Urban Continuum Code (2023)': 'Rur-Urb Cont. Code (2023)',
                   'Census Region': 'Census Reg.',
                   'Census Division': 'Census Div.',
                   'FNS Region': 'FNS Reg.'
                   }, inplace=True)
df
# Out:
#         FIPS State            County, State  Year Overall FI Rate  \
# 0       1001    AL  Autauga County, Alabama  2019           15.7%
# 1       1001    AL  Autauga County, Alabama  2020           14.5%
# 2       1001    AL  Autauga County, Alabama  2021           13.3%
# 3       1001    AL  Autauga County, Alabama  2022           15.1%
# 4       1001    AL  Autauga County, Alabama  2023           15.1%
# ...      ...   ...                      ...   ...             ...
# 15711  56045    WY   Weston County, Wyoming  2019           12.2%
# 15712  56045    WY   Weston County, Wyoming  2020           11.0%
# 15713  56045    WY   Weston County, Wyoming  2021           10.2%
# 15714  56045    WY   Weston County, Wyoming  2022           13.6%
# 15715  56045    WY   Weston County, Wyoming  2023           13.9%
#
#        # FI Persons Overall FI Rate Blk (all ethn) FI Hsp (any race)  \
# 0                      8670                    26%               NaN
# ...

# %%
df.dtypes
# Out:
# FIPS                                  int64
# State                                   str
# County, State                           str
# Year                                  int64
# Overall FI Rate                         str
# # FI Persons Overall                  Int64
# FI Rate Blk (all ethn)                  str
# FI Hsp (any race)                       str
# FI Rate Wht, non-Hsp                    str
# SNAP Thresh.                            str
# % FI ? SNAP Threshold                   str
# % FI > SNAP Threshold                   str
# Child FI Rate                           str
# # FI Children                         Int64
# % FI Children HH w/$ < 185 FPL          str
# % FI Children HH w/$ > 185 FPL          str
# $ Per Meal                              str
# Wghtd Wkly $ Needed by FI               str
# Wghtd Annual Food Budg Shortfall        str
# R-U Cont. Code (2013)               float64
# R-U Cont. Code (2023)               float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15716 entries, 0 to 15715
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State                             15716 non-null  str
#  1   County, State                     15716 non-null  str
#  2   Year                              15716 non-null  int64
#  3   Overall FI Rate                   15715 non-null  str
#  4   # FI Persons Overall              15715 non-null  Int64
#  5   FI Rate Blk (all ethn)            7432 non-null   str
#  6   FI Hsp (any race)                 8915 non-null   str
#  7   FI Rate Wht, non-Hsp              15442 non-null  str
#  8   SNAP Thresh.                      15716 non-null  str
#  9   % FI ? SNAP Threshold             15715 non-null  str
#  10  % FI > SNAP Threshold             15715 non-null  str
#  11  Child FI Rate                     15700 non-null  str
# ...

# %%
df.describe()
# Count = the number of values in each column
# Out:
#                Year  # FI Persons Overall  # FI Children  \
# count  15716.000000               15715.0        15715.0
# mean    2021.000318          12590.080178   12590.080178
# std        1.414236          40950.866318   40950.866318
# min     2019.000000                  10.0           10.0
# 25%     2020.000000                1470.0         1470.0
# 50%     2021.000000                3570.0         3570.0
# 75%     2022.000000                8980.0         8980.0
# max     2023.000000             1436270.0      1436270.0
#
#        R-U Cont. Code (2013)  R-U Cont. Code (2023)
# count           15694.000000            6288.000000
# mean                5.011979               5.249046
# std                 2.707610               2.929423
# min                 1.000000               1.000000
# 25%                 2.000000               2.000000
# 50%                 6.000000               6.000000
# 75%                 7.000000               8.000000
# ...

# %% [markdown]
# Next steps:
# 1. Figure out what to do with all of the NaN values.
# 2. Grouping and aggregating with .groupby()
# 3. Try grouping by years, filtering for specific years.
# 4. Sorting to find highest/lowest values or interesting outliers
# 5. Creating small summary tables that help answer early questions
#
# Start noting:
# 1. Surprises or unusual patterns
# 2. Gaps or limitations in the data
# 3. Trends worth visualizing
# 4. Questions that feel worth digging into
#
# Possible questions/analyses:
# 1. Compare trends over time (e.g., 2018 to 2023)
# 2. Compare states, regions
# 3. Compare counties within states
#
# Create at least:
# 1. One chart that shows a distribution (e.g., histogram, boxplot)
# 2. One chart that shows a comparison (e.g., bar chart, grouped bar, count plot)
# 3. One chart that shows a relationship or pattern (e.g., line chart, scatterplot)
#
# Consider (write down) these questions (that you will later add as markdown cells):
# 1. What question were you exploring?
# 2. What made you choose this type of chart?
# 3. What does the chart help you notice?
